# %%
import pandas as pd
from pandasql import sqldf

#reminder
from datetime import datetime
print(datetime.now())
# Out:
# 2020-10-22 20:22:19.166628

# %%
#creating dataframes

df_Census = pd.read_csv('Data_Sets/Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012-v2.csv')
df_Crime = pd.read_csv('Data_Sets/Chicago_Crime_Data-v2.csv')
df_Schools = pd.read_csv('Data_Sets/Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv')

# %%
type(df_Census)
# Out:
# pandas.core.frame.DataFrame

# %%
#creating SQL instance

pysqldf = lambda q: sqldf(q, globals())

# %%
#How many Crimes recorded?

record =  '''select count(id) as Total_Crime from df_Crime;'''
pysqldf(record)
# Out:
#    Total_Crime
# 0          533

# %% [markdown]
# ### Viewing the first 5 rows of data frames, in order to have general information about them.

# %%
df_Census_5 = '''select * from df_Census LIMIT 5;'''
df_Crime_5 = '''select * from df_Crime LIMIT 5;'''
df_Schools_5 = '''select * from df_Schools LIMIT 5;'''

# %%
pysqldf(df_Census_5)
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         ROGERS PARK                         7.7
# 1                    2.0          WEST RIDGE                         7.8
# 2                    3.0              UPTOWN                         3.8
# 3                    4.0      LINCOLN SQUARE                         3.4
# 4                    5.0        NORTH CENTER                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
pysqldf(df_Crime_5)
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  BEAT  DISTRICT  WARD  \
# 0            SMALL RETAIL STORE       0         0   911         9  14.0
# ...

# %%
pysqldf(df_Schools_5)
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
# How many crimes involve an arrest?

arrested = '''select count(id) as Arrested from df_Crime where arrest = 1;'''
pysqldf(arrested)
# Out:
#    Arrested
# 0       163

# %%
# Which unique types of crimes have been recorded at RESIDENCE locations?

Residence_Crimes = '''select distinct primary_type as In_Residence from df_Crime 
                        where location_description = 'RESIDENCE';'''
pysqldf(Residence_Crimes)
# Out:
#                         In_Residence
# 0                              THEFT
# 1                            BATTERY
# 2                    CRIMINAL DAMAGE
# 3                      OTHER OFFENSE
# 4                            ASSAULT
# 5                           BURGLARY
# 6                 DECEPTIVE PRACTICE
# 7                            ROBBERY
# 8                  CRIMINAL TRESPASS
# 9                       PROSTITUTION
# 10                 WEAPONS VIOLATION
# 11        OFFENSE INVOLVING CHILDREN
# 12                             ARSON
# 13                          STALKING
# 14                         OBSCENITY
# 15  NON-CRIMINAL (SUBJECT SPECIFIED)

# %%
# In the CENSUS_DATA table list all Community Areas whose names start with the letter ‘W’

Census_w = ''' select COMMUNITY_AREA_NAME from df_Census where COMMUNITY_AREA_NAME like 'W%'  '''
pysqldf(Census_w)
# Out:
#   COMMUNITY_AREA_NAME
# 0          West Ridge
# 1           West Town
# 2  West Garfield Park
# 3     Washington Park
# 4            Woodlawn
# 5        West Pullman
# 6         West Elsdon
# 7           West Lawn
# 8      West Englewood
# 9   Washington Height

# %%
# Which schools are defined as 'safety school' in Lincoln Park. 

Safety_Schools = '''select name_of_school from df_Schools where community_area_name = 'LINCOLN PARK' 
                    and  healthy_school_certified = 'Yes';'''
pysqldf(Safety_Schools)
# Out:
#                       NAME_OF_SCHOOL
# 0  Abraham Lincoln Elementary School

# %%
# What is the average school Safety Score?

Average_Safety = '''select AVG(safety_score) as Average_Safety_Score from df_Schools;'''
pysqldf(Average_Safety)
# Out:
#    Average_Safety_Score
# 0             49.504873

# %%
df_Schools.shape
# Out:
# (566, 78)

# %%
df_Crime.shape
# Out:
# (533, 22)

# %%
df_Census.shape
# Out:
# (78, 9)

# %%
# to view all columns
pd.set_option('display.max_columns', 78)

# %%
# Top 5 safe areas.
Safer_Areas = '''select community_area_name as Community_Areas, avg(safety_score) as Average_Safety_Score 
                 from df_Schools group by community_area_name order by avg(safety_score) desc LIMIT 5;'''
pysqldf(Safer_Areas)
# Out:
#    Community_Areas  Average_Safety_Score
# 0      FOREST GLEN             99.000000
# 1             LOOP             92.000000
# 2  MOUNT GREENWOOD             86.500000
# 3     NORTH CENTER             85.166667
# 4     LINCOLN PARK             81.833333

# %%
# Average Hardship Index (Top 5)
avr_hardship = '''select community_area_name as Community_Areas, HARDSHIP_INDEX
                  as Hardship_Index from df_Census
                  group by community_area_name order by HARDSHIP_INDEX desc LIMIT 5;'''
pysqldf(avr_hardship)
# Out:
#   Community_Areas  Hardship_Index
# 0       Riverdale            98.0
# 1     Fuller Park            97.0
# 2  South Lawndale            96.0
# 3       Englewood            94.0
# 4       Gage Park            93.0

# %%
# Hardship Index (Min 5)
avr_hardship = '''select community_area_name as Community_Areas, HARDSHIP_INDEX
                  as Hardship_Index from df_Census
                  group by community_area_name order by HARDSHIP_INDEX LIMIT 5;'''
pysqldf(avr_hardship)
# Out:
#    Community_Areas  Hardship_Index
# 0          CHICAGO             NaN
# 1  Near North Side             1.0
# 2     Lincoln Park             2.0
# 3             Loop             3.0
# 4        Lake View             5.0

# %%
# Average Hardship Index
chicago_hardship = '''select COMMUNITY_AREA_NAME, HARDSHIP_INDEX from df_Census where COMMUNITY_AREA_NAME = 'CHICAGO';'''
pysqldf(chicago_hardship)
# Out:
#   COMMUNITY_AREA_NAME HARDSHIP_INDEX
# 0             CHICAGO           None

# %%
chicago_row = '''select * from df_Census where COMMUNITY_AREA_NAME = 'Near North Side';'''
pysqldf(chicago_row)
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                    8.0     Near North Side                         1.9
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              12.9                          7.0
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           2.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER_CAPITA_INCOME   HARDSHIP_INDEX
# 0                              22.6               88669             1.0

# %%
# Delete false row
df_Census = df_Census[df_Census['COMMUNITY_AREA_NAME'] !='CHICAGO']

# %%
# Hardship Index (Min 5)
avr_hardship = '''select community_area_name as Community_Areas, HARDSHIP_INDEX
                  as Hardship_Index from df_Census
                  group by community_area_name order by HARDSHIP_INDEX LIMIT 5;'''
pysqldf(avr_hardship)
# Out:
#    Community_Areas  Hardship_Index
# 0  Near North Side             1.0
# 1     Lincoln Park             2.0
# 2             Loop             3.0
# 3        Lake View             5.0
# 4     North Center             6.0

# %%
area_income = '''select PER_CAPITA_INCOME from df_Census'''
pysqldf(area_income)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# OperationalError: no such column: PER_CAPITA_INCOME
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
# We can get a result by writing the column names with spaces at the end in reverse quotes.
area_income = '''select `PER_CAPITA_INCOME ` from df_Census'''
pysqldf(area_income)
# Out:
#     PER_CAPITA_INCOME
# 0                23939
# 1                23040
# 2                35787
# 3                37524
# 4                57123
# ..                 ...
# 72               19713
# 73               34381
# 74               27149
# 75               25828
# 76               33385
#
# [77 rows x 1 columns]

# %%
df_Census.columns
# Out:
# Index(['COMMUNITY_AREA_NUMBER', 'COMMUNITY_AREA_NAME',
#        'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER_CAPITA_INCOME ',
#        'HARDSHIP_INDEX'],
#       dtype='object')

# %%
df_Census['COMMUNITY_AREA_NAME'] = df_Census['COMMUNITY_AREA_NAME'].str.upper()

# %%
# Relationship between crime rate and mean income.

crime_income = '''select df_Census.community_area_name as Area_Name, avg(df_Census.`PER_CAPITA_INCOME `) as Income,
                df_Schools.SAFETY_SCORE from df_Census JOIN df_Schools on 
                df_Census.community_area_name = df_Schools.community_area_name group by Area_Name order by Area_Name;'''

pysqldf(crime_income)
# Out:
#          Area_Name   Income  SAFETY_SCORE
# 0      ALBANY PARK  21323.0           NaN
# 1   ARCHER HEIGHTS  16134.0          43.0
# 2    ARMOUR SQUARE  16148.0          32.0
# 3          ASHBURN  23482.0          20.0
# 4   AUBURN GRESHAM  15528.0           NaN
# ..             ...      ...           ...
# 69       WEST LAWN  16907.0          42.0
# 70    WEST PULLMAN  16563.0           NaN
# 71      WEST RIDGE  23040.0          47.0
# 72       WEST TOWN  43198.0          31.0
# 73        WOODLAWN  18672.0           NaN
#
# [74 rows x 3 columns]

# %%
# to prevent NaN values not affecting the average.

crime_income_nan = '''select df_Census.community_area_name as Area_Name, df_Census.`PER_CAPITA_INCOME ` as Income,
                df_Schools.SAFETY_SCORE from df_Census JOIN df_Schools on 
                df_Census.community_area_name = df_Schools.community_area_name 
                where df_Schools.SAFETY_SCORE is not null order by Area_Name ;'''

pysqldf(crime_income_nan)
# Out:
#        Area_Name  Income  SAFETY_SCORE
# 0    ALBANY PARK   21323          66.0
# 1    ALBANY PARK   21323          43.0
# 2    ALBANY PARK   21323          43.0
# 3    ALBANY PARK   21323          75.0
# 4    ALBANY PARK   21323          67.0
# ..           ...     ...           ...
# 497     WOODLAWN   18672          19.0
# 498     WOODLAWN   18672          31.0
# 499     WOODLAWN   18672          29.0
# 500     WOODLAWN   18672          13.0
# 501     WOODLAWN   18672          70.0
#
# [502 rows x 3 columns]

# %%
# Relationship between crime rate and mean income.

crime_income = '''select df_Census.community_area_name as Area_Name, avg(df_Census.`PER_CAPITA_INCOME `) as Income,
                df_Schools.SAFETY_SCORE from df_Census JOIN df_Schools on 
                df_Census.community_area_name = df_Schools.community_area_name 
                where df_Schools.SAFETY_SCORE is not null
                group by Area_Name order by Income;'''

df_income_safety = pysqldf(crime_income)
df_income_safety
# Out:
#              Area_Name   Income  SAFETY_SCORE
# 0            RIVERDALE   8201.0          53.0
# 1       SOUTH LAWNDALE  10402.0          40.0
# 2          FULLER PARK  10432.0          38.0
# 3   WEST GARFIELD PARK  10934.0          41.0
# 4       WEST ENGLEWOOD  11317.0          31.0
# ..                 ...      ...           ...
# 68     NEAR SOUTH SIDE  59077.0          67.0
# 69           LAKE VIEW  60058.0          73.0
# 70                LOOP  65526.0          92.0
# 71        LINCOLN PARK  71551.0          99.0
# 72     NEAR NORTH SIDE  88669.0          50.0
#
# [73 rows x 3 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.style.use('seaborn')
Income = df_income_safety['Income']
Safety = df_income_safety['SAFETY_SCORE']
plt.scatter(Income, Safety, edgecolor='black', linewidth=1, alpha=0.75)
plt.title('Income & Safety')
plt.xlabel('Income')
plt.ylabel('Safety Score')
plt.tight_layout()

# %% [markdown]
# > It can be said that Safety Score and Income are positif relation to each other.
